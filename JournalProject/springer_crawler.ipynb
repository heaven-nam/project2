# %%
from requests import get
from bs4 import BeautifulSoup
import re
import pandas as pd
from urllib.parse import urlencode, parse_qs, urlparse
import time
import random
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://link.springer.com/search/page/2?facet-language=%22En%22&facet-discipline=%22Mathematics%22&query=harmonic+analysis&facet-content-type=%22Article%22'
parsed = urlparse(url)
qs = parse_qs(parsed.query)

# %%
df = pd.DataFrame(columns=['title','abstract','author','journal','year','pdf_link','keyword'])

# %%
for k,v in qs.items():
    qs[k] = v[0]

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}

# %%
urls = list()
visited = list()
pages = list(range(1,21))
baseurl = 'https://link.springer.com'

for page in pages:
    url = 'https://link.springer.com/search/page/' + str(page) + '?' + urlencode(qs)
    urls.append((url,0))

while urls:
    seed = urls.pop(0)
    visited.append(seed[0])
    
    resp = get(seed[0], headers=headers)
    
    if resp.status_code != 200:
        print(resp)
        break
        
    else:
        data = dict()
        dom = BeautifulSoup(resp.text, 'html.parser')
        if seed[1] == 0:
            ol = dom.find('ol',attrs={'id':'results-list'})
            li = ol.find_all('li',recursive=False)
            for l in li:
                a = l.find('a',attrs={'class':'title'})
                link = baseurl + a.attrs['href']
                if link not in (visited and urls):
                    urls.append((link,1))
        if seed[1] == 1:
            resp = get(seed[0], headers = headers)
            dom = BeautifulSoup(resp.text, 'html.parser')
            try:
                title = dom.find('h1', attrs={'class':'c-article-title'}).text
                data['title'] = [title]
                abst = dom.find('div', attrs={'id':'Abs1-content'})
                data['abstract'] = [abst.text]
                author = dom.find('ul', attrs={'data-test':'authors-list'})
                data['author'] = author.text[:-2]
                journal = dom.find('a', attrs={'data-test':'journal-link'}).text
                data['journal'] = [journal]
                year = dom.find('span', attrs={'data-test':'article-publication-year'}).text
                data['year'] = [year]
                data['pdf_link'] = [seed[0]]
                keywords = list()
                keyul = dom.find('ul', attrs={'class':'c-article-subject-list'}).find_all('li', recursive=False)
                for key in keyul:
                    keywords.append(key.text)
                data['keyword'] = [','.join(keywords)]
                data = pd.DataFrame(data)
                df = pd.concat([df,data])
                visited.append(seed[0])
            except:
                continue
    sleeping = random.randrange(0,3)
    print('sleep for {}s'.format(sleeping))
    time.sleep(sleeping)
# Out:
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 2s
# sleep for 1s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 1s
# sleep for 0s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 1s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 0s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 1s
# sleep for 2s
# sleep for 2s
# sleep for 0s
# sleep for 2s
# sleep for 0s
# sleep for 1s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 322 entries, 0 to 0
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     322 non-null    object
#  1   abstract  322 non-null    object
#  2   author    322 non-null    object
#  3   journal   322 non-null    object
#  4   year      322 non-null    object
#  5   pdf_link  322 non-null    object
#  6   keyword   322 non-null    object
# dtypes: object(7)
# memory usage: 20.1+ KB

# %%
df
# Out:
#                                                 title  \
# 0   Blow-up analysis for approximate Dirac-harmoni...
# 0            On harmonic analysis of causal operators
# 0   Harmonic analysis on the infinite-dimensional ...
# 0    Some approximation problems in harmonic analysis
# 0              Symmetry problems in harmonic analysis
# ..                                                ...
# 0   Quasiconformal Harmonic Mappings Between the U...
# 0   Positive Harmonic Functions that Vanish on a S...
# 0   On Kähler manifolds with harmonic Bochner curv...
# 0   Periodic harmonic functions on lattices and po...
# 0   Phragmén-Lindelöf Theorems and p-harmonic Meas...
#
#                                              abstract  \
# 0   Dirac-harmonic maps couple a second order harm...
# 0   We follow the group representation theory appr...
# 0   The goal of harmonic analysis on the infinite-...
# 0   Consideriamo il seguente problema: determinare...
# 0   Symmetry problems in harmonic analysis are for...
# ..                                                ...
# 0   We prove the following. If f is a harmonic qua...
# 0   This paper investigates positive harmonic func...
# 0   We prove that every irreducible Kähler manifol...
# 0   This survey deals with pluri-periodic harmonic...
# 0   We prove estimates of a p-harmonic measure, p∈...
#
#                                    author  \
# 0   Jürgen Jost1, Lei Liu1 & Miaomiao Zhu
# 0        A. G. Baskakov1 & I. A. Krishtal
# 0                          A. A. Osinenko
# 0                     Gregory F. Bachelis
# 0                       Alexander G. Ramm
# ..                                    ...
# 0             Anton Gjokaj1 & David Kalaj
# 0            Marius Ghergu1 & Joanna Pres
# 0                              Jaeman Kim
# 0                      Mikhail Zaidenberg
# 0                  Niklas L. P. Lundström
#
#                                               journal  year  \
# 0   Calculus of Variations and Partial Differentia...  2017
# 0            Functional Analysis and Its Applications  2006
# 0                    Journal of Mathematical Sciences  2012
# 0   Rendiconti del Seminario Matematico e Fisico d...  1978
# 0                                        SeMA Journal  2021
# ..                                                ...   ...
# 0                                  Potential Analysis  2022
# 0                                  Potential Analysis  2009
# 0              Annals of Global Analysis and Geometry  2009
# 0             Central European Journal of Mathematics  2009
# 0                                  Potential Analysis  2016
#
#                                              pdf_link  \
# 0   https://link.springer.com/article/10.1007/s005...
# 0   https://link.springer.com/article/10.1007/s106...
# 0   https://link.springer.com/article/10.1007/s109...
# 0   https://link.springer.com/article/10.1007/BF02...
# 0   https://link.springer.com/article/10.1007/s403...
# ..                                                ...
# 0   https://link.springer.com/article/10.1007/s111...
# 0   https://link.springer.com/article/10.1007/s111...
# 0   https://link.springer.com/article/10.1007/s104...
# 0   https://link.springer.com/article/10.2478/s115...
# 0   https://link.springer.com/article/10.1007/s111...
#
#                                               keyword
# 0                                       53C43 (58E20)
# 0   causal operator,representation of a locally co...
# 0   Harmonic Analysis,Point Process,Symmetric Grou...
# 0   Banach Algebra,Trigonometric Polynomial,Uncond...
# 0                                    Symmetry problem
# ..                                                ...
# 0   Harmonic mappings,Quasiconformal mappings,Höld...
# 0   Minimal harmonic functions,Harmonic measure,De...
# 0   Irreducible Kähler manifold,Harmonic Bochner c...
# 0                 11B39,11T06,11T99,31C05,37B15,43A99
# 0   Global estimates,Growth of p-harmonic function...
#
# [322 rows x 7 columns]

# %% [markdown]
# df.to_csv('springer_test_1128.csv')

# %%
df[['title','abstract']].to_csv('springer_ta.csv')

# %%
' '.join(df.iloc[0].abstract.split('\n'))
# Out:
# 'Dirac-harmonic maps couple a second order harmonic map type system with a first nonlinear Dirac equation. We consider approximate Dirac-harmonic maps \\(\\{(\\phi _n,\\psi _n)\\}\\), that is, maps that satisfy the Dirac-harmonic system up to controlled error terms. We show that such approximate Dirac-harmonic maps defined on a Riemann surface, that is, in dimension 2, continue to satisfy the basic properties of blow-up analysis like the energy identity and the no neck property. The assumptions are such that they hold for solutions of the heat flow of Dirac-harmonic maps. That flow turns the harmonic map type system into a parabolic system, but simply keeps the Dirac equation as a nonlinear first order constraint along the flow. As a corollary of the main result of this paper, when such a flow blows up at infinite time at interior points, we obtain an energy identity and the no neck property.'

# %%
df.iloc[0].abstract
# Out:
# 'Dirac-harmonic maps couple a second order harmonic map type system with a first nonlinear Dirac equation. We consider approximate Dirac-harmonic maps \\(\\{(\\phi _n,\\psi _n)\\}\\), that is, maps that satisfy the Dirac-harmonic system up to controlled error terms. We show that such approximate Dirac-harmonic maps defined on a Riemann surface, that is, in dimension 2, continue to satisfy the basic properties of blow-up analysis like the energy identity and the no neck property. The assumptions are such that they hold for solutions of the heat flow of Dirac-harmonic maps. That flow turns the harmonic map type system into a parabolic system, but simply keeps the Dirac equation as a nonlinear first order constraint along the flow. As a corollary of the main result of this paper, when such a flow blows up at infinite time at interior points, we obtain an energy identity and the no neck property.'

# %%
def toOneline(x):
    return ' '.join(x.split('\n'))

# %%
df.abstract =df.abstract.apply(toOneline)

# %%
df[['title','abstract']].to_csv('ta_test.csv')
